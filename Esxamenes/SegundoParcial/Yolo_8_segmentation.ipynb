# %% [markdown]
# # ***SEMANTIC SEGMENTATION USING YOLO_8 MODEL***

# %% [markdown]
# # **Dataset**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Instala ultralytics
# %pip install ultralytics
# Importa libreria ultralytics
import ultralytics
from ultralytics import YOLO

from IPython.display import display, Image
# Revisa y visualiza las capacidades computacionales del computador virtual
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.2/78.2 GB disk)

# %% [markdown]
# # ***YOLO_8 MODEL***

# %%
from ultralytics import settings

# Update a setting
settings.update({'runs_dir': '/content/drive/MyDrive/IA_II/Segmentation/Yolo_8/runs'})

# %%
# !yolo task=detect mode=train model=yolov8n-seg.pt data= /content/dataset-29/data.yaml epochs=2 imgsz=640 plots=True save_period=1
# !yolo task=detect mode=train model=yolov8l-seg.pt data= /content/Second_Exam_AI_beans-1/data.yaml epochs=10 imgsz=640 plots=True save_period=1
# !yolo task=detect mode=train resume model=/content/drive/MyDrive/JMB/checkpoints/last_25102023_0251_l.pt data= /content/drive/MyDrive/JMB/dataset/data.yaml epochs=40 imgsz=640 plots=True save_period=1
# Out:
# ...
# 100% 88.1M/88.1M [00:00<00:00, 264MB/s]
# WARNING ⚠️ conflicting 'task=detect' passed with 'task=segment' model. Ignoring 'task=detect' and updating to 'task=segment' to match model.
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Image(filename='/content/drive/MyDrive/IA_II/Segmentation/Yolo_8/runs/segment/train/confusion_matrix_normalized.png', width=1300)

# %%
Image(filename='/content/drive/MyDrive/IA_II/Segmentation/Yolo_8/runs/segment/train/val_batch1_pred.jpg', width=1300)

# %%
Image(filename='/content/drive/MyDrive/IA_II/Segmentation/Yolo_8/runs/segment/train/val_batch1_labels.jpg', width=1300)

# %%
Image(filename='/content/drive/MyDrive/IA_II/Segmentation/Yolo_8/runs/segment/train/results.png', width=1300)
